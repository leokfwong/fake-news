# %%
import pandas as pd
import os
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-a083f95409d0> in <module>
#       1 import pandas as pd
#       2 import os
# ----> 3 from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
df = pd.DataFrame()
for filename in os.listdir('datasets'):
     df = df.append(pd.read_csv('datasets/' + filename, dtype={'label':str}), ignore_index=True)

df
# Out:
#        index        label                                              quote  \
# 0          0  barely-true  “When large numbers of people in Butler (Pa.) ...
# 1          1  barely-true  Broken voting machines in Russellville, Ark., ...
# 2          2  barely-true  Pennsylvania officials are “attempting to sile...
# 3          3  barely-true  In Massachusetts, "anybody can go vote for any...
# 4          4  barely-true  “Joe Biden and Kamala Harris’ government-run h...
# ...      ...          ...                                                ...
# 18003   2249         true  MikeHuckabee.com gets "more hits than virtuall...
# 18004   2250         true  I saved the taxpayers $2-billion on a bogus Ai...
# 18005   2251         true  I get the most money from active duty officers...
# 18006   2252         true  In the African-American community today, 68 pe...
# 18007   2253         true  The mayor said … 'if you happen to be in this ...
#
#                                 context          author               date  \
# 0                  a Fox News broadcast  Tucker Carlson   November 2, 2020
# 1                    a post on Facebook     Viral image   October 21, 2020
# 2                       a Facebook post  Facebook posts   November 2, 2020
# 3              a video posted on TikTok    TikTok posts  September 1, 2020
# 4                               a TV ad    Donald Trump   October 28, 2020
# ...                                 ...             ...                ...
# 18003             interview on Fox News   Mike Huckabee  November 14, 2007
# 18004              St. Petersburg, Fla.     John McCain  November 28, 2007
# 18005        a debate in St. Petersburg        Ron Paul  November 28, 2007
# 18006              St. Petersburg, Fla.     Mitt Romney  November 28, 2007
# 18007  a debate in St. Petersburg, Fla.     Mitt Romney  November 28, 2007
#
#                                          categories            staff
# 0              National, Drugs, Pundits, PunditFact    Jon Greenberg
# 1                   Elections, Facebook Fact-checks    Bill McCarthy
# 2      Elections, Facebook Fact-checks, Coronavirus   Ciara O'Rourke
# 3                          Elections, Voter ID Laws  Miriam Valverde
# 4                             National, Health Care      Amy Sherman
# ...                                             ...              ...
# 18003                           National, Elections   Cristina Silva
# 18004                      National, Federal Budget        Tom Tobin
# 18005                              National, Ethics       Janet Zink
# 18006                            National, Families       Janet Zink
# 18007                         Immigration, National       Bill Adair
#
# [18008 rows x 8 columns]

# %%
df['author'].value_counts()
# Out:
# Facebook posts                   1002
# Donald Trump                      899
# Bloggers                          595
# Barack Obama                      554
# Viral image                       545
#                                  ...
# Brian Fallon                        1
# Brandon Morse                       1
# The Freedom Project                 1
# Nevada State Democratic Party       1
# USF Divest                          1
# Name: author, Length: 4242, dtype: int64

# %%
# split the dataset into training and validation datasets 
train_x, valid_x, train_y, valid_y = model_selection.train_test_split(trainDF['text'], trainDF['label'])

# label encode the target variable 
encoder = preprocessing.LabelEncoder()
train_y = encoder.fit_transform(train_y)
valid_y = encoder.fit_transform(valid_y)

# %%
# word level tf-idf
tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', max_features=5000)
tfidf_vect.fit(trainDF['text'])
xtrain_tfidf =  tfidf_vect.transform(train_x)
xvalid_tfidf =  tfidf_vect.transform(valid_x)
# Out:
# the        13947
# of          8048
# in          7919
# to          7799
# a           6171
# and         4960
# Says        4522
# for         3415
# that        3041
# is          3001
# on          2152
# have        2061
# The         2044
# are         1975
# has         1823
# than        1764
# was         1543
# by          1396
# with        1386
# from        1385
# percent     1346
# more        1308
# as          1159
# not         1056
# people       975
# at           952
# it           939
# be           936
# our          932
# tax          919
# dtype: int64
